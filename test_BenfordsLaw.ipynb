# %%
from benfordslaw import benfordslaw

# Initialize
bl = benfordslaw(alpha=0.05)

# Load elections example
df = bl.import_example(data='USA')

# Extract election information.
X = df['votes'].loc[df['candidate']=='Donald Trump'].values

# Print
print(X)
# array([ 5387, 23618,  1710, ...,    16,    21,     0], dtype=int64)

# Make fit
results = bl.fit(X)

# Plot
bl.plot(title='Donald Trump')
# Out:
# [benfordslaw] >Downloading [USA] dataset from github source..
# [benfordslaw] >Import dataset [USA]
# [ 5387 23618  1710 ...    16    21     0]
# [benfordslaw] >Analyzing digit position: [1]
# [benfordslaw] >[chi2] No anomaly detected. P=0.422984, Tstat=8.10808
# (<Figure size 1080x576 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7fa9f7e990d0>)

# %%
# last digit-distribution
from benfordslaw import benfordslaw

# Initialize and set to analyze the last digit postion
bl = benfordslaw(pos=-1)
# USA example
df = bl.import_example(data='USA')
results = bl.fit(X)
# Plot
bl.plot(title='Donald Trump', barcolor=[0.5, 0.5, 0.5], fontsize=12, barwidth=0.4)
# Out:
# [benfordslaw] >Import dataset [USA]
# [benfordslaw] >Analyzing digit position: [-1]
# [benfordslaw] >[chi2] Anomaly detected! P=1.07833e-305, Tstat=1440.33
# (<Figure size 1080x576 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7fa9f7aff150>)

# %%
# Analyze second last digit-distribution
from benfordslaw import benfordslaw

# Initialize and set to analyze the last postion
bl = benfordslaw(pos=-2)
# USA example
df = bl.import_example(data='USA')
results = bl.fit(X)
# Plot
bl.plot(title='Donald Trump', barcolor=[0.5, 0.5, 0.5], fontsize=12, barwidth=0.4)
# Out:
# [benfordslaw] >Import dataset [USA]
# [benfordslaw] >Analyzing digit position: [-2]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/.conda/envs/my37g/lib/python3.7/site-packages/benfordslaw/benfordslaw.py in fit(self, X)
#     109             try:
# --> 110                 tstats, Praw = chisquare(counts_emp, f_exp=counts_exp)
#     111             except:
#
# ~/.conda/envs/my37g/lib/python3.7/site-packages/scipy/stats/stats.py in chisquare(f_obs, f_exp, ddof, axis)
#    6852     return power_divergence(f_obs, f_exp=f_exp, ddof=ddof, axis=axis,
# -> 6853                             lambda_="pearson")
#    6854
#
# ~/.conda/envs/my37g/lib/python3.7/site-packages/scipy/stats/stats.py in power_divergence(f_obs, f_exp, ddof, axis, lambda_)
#    6693                    f"{relative_diff}")
# -> 6694             raise ValueError(msg)
#    6695
#
# ValueError: For each axis slice, the sum of the observed frequencies must agree with the sum of the expected frequencies to a relative tolerance of 1e-08, but the percent differences are:
# 0.0002797985450475658
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# /tmp/ipykernel_1689/3212308353.py in <module>
#       6 # USA example
#       7 df = bl.import_example(data='USA')
# ----> 8 results = bl.fit(X)
#       9 # Plot
#      10 bl.plot(title='Donald Trump', barcolor=[0.5, 0.5, 0.5], fontsize=12, barwidth=0.4)
#
# ~/.conda/envs/my37g/lib/python3.7/site-packages/benfordslaw/benfordslaw.py in fit(self, X)
#     110                 tstats, Praw = chisquare(counts_emp, f_exp=counts_exp)
#     111             except:
# --> 112                 raise Exception('The relative tolerance of the chisquare test is not reached. Try using another method such as "method=ks". This is not a bug but a feature: "https://github.com/scipy/scipy/issues/13362" ')
#     113         elif self.method=='ks':
#     114             tstats, Praw = ks_2samp(counts_emp, counts_exp)
#
# Exception: The relative tolerance of the chisquare test is not reached. Try using another method such as "method=ks". This is not a bug but a feature: "https://github.com/scipy/scipy/issues/13362"
